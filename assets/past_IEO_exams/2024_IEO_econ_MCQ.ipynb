# %% [markdown]
# Extract data from excel

# %%
import pandas as pd

# %%
df = pd.read_excel("../excels/2024_IEO_econ_MCQ_PersonalScores.xlsx")
df
# Out:
#     Question                       title  \
# 0          1        Price Discrimination
# 1          2                  Entry Game
# 2          3            Opportunity Cost
# 3          4           Consumer Behavior
# 4          5                       Taxes
# 5          6  Price Elasticity of Demand
# 6          7  Price Elasticity of Demand
# 7          8                       Taxes
# 8          9            Monopoly Pricing
# 9         10                  Output Gap
# 10        11                       Taxes
# 11        12          Free-rider problem
# 12        13               Externalities
# 13        14                  Inequality
# 14        15           Transaction Costs
# 15        16                Unemployment
# 16        17                 Nobel Prize
# 17        18             Monetary Policy
# 18        19               Fiscal Policy
# 19        20                   Stagation
#
#                         Topic (my opinion)  \
# ...
